# %%
import pandas as pd

# %%
series=pd.Series(["BMW","Ferrari","Bollaro"])
series
#Series 1-dimentional
# Out:
# 0        BMW
# 1    Ferrari
# 2    Bollaro
# dtype: object

# %%
colours=pd.Series(["red","yellow","White"])
colours
# Out:
# 0       red
# 1    yellow
# 2     White
# dtype: object

# %%
car_data=pd.DataFrame({"Car make":series,"Colour":colours})
car_data
# Out:
#   Car make  Colour
# 0      BMW     red
# 1  Ferrari  yellow
# 2  Bollaro   White

# %%
car_sales=pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv("exported_car_sales.csv",index=False)

# %%
export_car_sales=pd.read_csv("exported_car_sales.csv")
export_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# #describe data

# %%
# car_sales.dtypes
# car_sales
car_sales.info()
car_sales.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns=car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.mean  
#give mean
# Out:
# <bound method DataFrame.mean of      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00>

# %%
car_prices=pd.Series([3000,1500,111250])
car_prices.mean()
# Out:
# np.float64(38583.333333333336)

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# np.int64(40)

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %% [markdown]
#  ## Index return

# %%
animals=pd.Series(["dog","cat","bird","panda","snake"],index=[0,3,1,3,8])
animals
# Out:
# 0      dog
# 3      cat
# 1     bird
# 3    panda
# 8    snake
# dtype: object

# %%
#Location==loc
animals.loc[3]
# Out:
# 3      cat
# 3    panda
# dtype: object

# %%
animals.loc[8]
# Out:
# 'snake'

# %%
# loc refers to key position
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# .iloc  refers to index position
animals.iloc[2]
# Out:
# 'bird'

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales["Make"]  #print columns
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Make"]=="Toyota"]  #condtion give where in Make Toyota
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales["Make"]=car_sales["Make"].str.lower()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %%
car_sales_missing=pd.read_csv("test_car_new.csv")
car_sales_missing
# Out:
#             id          brand                   model  model_year  milage  \
# 0       188533           Land          Rover LR2 Base        2015   98000
# 1       188534           Land       Rover Defender SE        2020    9142
# 2       188535           Ford      Expedition Limited        2022   28121
# 3       188536           Audi           A6 2.0T Sport        2016   61258
# 4       188537           Audi    A6 2.0T Premium Plus        2018   59000
# ...        ...            ...                     ...         ...     ...
# 125685  314218  Mercedes-Benz  GL-Class GL 450 4MATIC        2014   83315
# 125686  314219           Audi          Q7 55 Prestige        2019   29336
# 125687  314220           Audi    A6 3.0T Premium Plus        2012   77634
# 125688  314221           Audi         Q7 3.0T Premium        2012  112000
# 125689  314222      Chevrolet                Tahoe LT        2018   66840
#
#        fuel_type                                             engine  \
# ...

# %%
car_sales_missing.isnull().sum()
# Out:
# id                  0
# brand               0
# model               0
# model_year          0
# milage              0
# fuel_type        3383
# engine              0
# transmission        0
# ext_col             0
# int_col             0
# accident         1632
# clean_title     14239
# dtype: int64

# %%
car_sales_missing=car_sales_missing.dropna()

# %%
car_sales_missing
# Out:
#             id          brand                   model  model_year  milage  \
# 0       188533           Land          Rover LR2 Base        2015   98000
# 1       188534           Land       Rover Defender SE        2020    9142
# 4       188537           Audi    A6 2.0T Premium Plus        2018   59000
# 5       188538      Chevrolet   Express 2500 Work Van        2013   99524
# 6       188539          Lexus             RX 350 Base        2008  194000
# ...        ...            ...                     ...         ...     ...
# 125683  314216  Mercedes-Benz  GL-Class GL 450 4MATIC        2011  192000
# 125685  314218  Mercedes-Benz  GL-Class GL 450 4MATIC        2014   83315
# 125687  314220           Audi    A6 3.0T Premium Plus        2012   77634
# 125688  314221           Audi         Q7 3.0T Premium        2012  112000
# 125689  314222      Chevrolet                Tahoe LT        2018   66840
#
#        fuel_type                                             engine  \
# ...

# %%
#Add new columns
car_sales_missing["Seats"]=pd.Series([5,5,5,5,5,5,5,5,5])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5276\245698139.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_sales_missing["Seats"]=pd.Series([5,5,5,5,5,5,5,5,5])

# %%
car_sales_missing
# Out:
#             id          brand                   model  model_year  milage  \
# 0       188533           Land          Rover LR2 Base        2015   98000
# 1       188534           Land       Rover Defender SE        2020    9142
# 4       188537           Audi    A6 2.0T Premium Plus        2018   59000
# 5       188538      Chevrolet   Express 2500 Work Van        2013   99524
# 6       188539          Lexus             RX 350 Base        2008  194000
# ...        ...            ...                     ...         ...     ...
# 125683  314216  Mercedes-Benz  GL-Class GL 450 4MATIC        2011  192000
# 125685  314218  Mercedes-Benz  GL-Class GL 450 4MATIC        2014   83315
# 125687  314220           Audi    A6 3.0T Premium Plus        2012   77634
# 125688  314221           Audi         Q7 3.0T Premium        2012  112000
# 125689  314222      Chevrolet                Tahoe LT        2018   66840
#
#        fuel_type                                             engine  \
# ...

# %%
car_sales_missing["Seats"].fillna(5,inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5276\1991472231.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales_missing["Seats"].fillna(5,inplace=True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5276\1991472231.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_sales_missing["Seats"].fillna(5,inplace=True)

# %%
car_sales_missing
# Out:
#             id          brand                   model  model_year  milage  \
# 0       188533           Land          Rover LR2 Base        2015   98000
# 1       188534           Land       Rover Defender SE        2020    9142
# 4       188537           Audi    A6 2.0T Premium Plus        2018   59000
# 5       188538      Chevrolet   Express 2500 Work Van        2013   99524
# 6       188539          Lexus             RX 350 Base        2008  194000
# ...        ...            ...                     ...         ...     ...
# 125683  314216  Mercedes-Benz  GL-Class GL 450 4MATIC        2011  192000
# 125685  314218  Mercedes-Benz  GL-Class GL 450 4MATIC        2014   83315
# 125687  314220           Audi    A6 3.0T Premium Plus        2012   77634
# 125688  314221           Audi         Q7 3.0T Premium        2012  112000
# 125689  314222      Chevrolet                Tahoe LT        2018   66840
#
#        fuel_type                                             engine  \
# ...

# %%
car_sales_missing["No of wheels"]=4
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5276\3116285030.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_sales_missing["No of wheels"]=4

# %%
car_sales_missing
# Out:
#             id          brand                   model  model_year  milage  \
# 0       188533           Land          Rover LR2 Base        2015   98000
# 1       188534           Land       Rover Defender SE        2020    9142
# 4       188537           Audi    A6 2.0T Premium Plus        2018   59000
# 5       188538      Chevrolet   Express 2500 Work Van        2013   99524
# 6       188539          Lexus             RX 350 Base        2008  194000
# ...        ...            ...                     ...         ...     ...
# 125683  314216  Mercedes-Benz  GL-Class GL 450 4MATIC        2011  192000
# 125685  314218  Mercedes-Benz  GL-Class GL 450 4MATIC        2014   83315
# 125687  314220           Audi    A6 3.0T Premium Plus        2012   77634
# 125688  314221           Audi         Q7 3.0T Premium        2012  112000
# 125689  314222      Chevrolet                Tahoe LT        2018   66840
#
#        fuel_type                                             engine  \
# ...

# %%
car_sales_missing=car_sales_missing.drop("clean_title",axis=1)

# %%
car_sales_missing
# Out:
#             id          brand                   model  model_year  milage  \
# 0       188533           Land          Rover LR2 Base        2015   98000
# 1       188534           Land       Rover Defender SE        2020    9142
# 4       188537           Audi    A6 2.0T Premium Plus        2018   59000
# 5       188538      Chevrolet   Express 2500 Work Van        2013   99524
# 6       188539          Lexus             RX 350 Base        2008  194000
# ...        ...            ...                     ...         ...     ...
# 125683  314216  Mercedes-Benz  GL-Class GL 450 4MATIC        2011  192000
# 125685  314218  Mercedes-Benz  GL-Class GL 450 4MATIC        2014   83315
# 125687  314220           Audi    A6 3.0T Premium Plus        2012   77634
# 125688  314221           Audi         Q7 3.0T Premium        2012  112000
# 125689  314222      Chevrolet                Tahoe LT        2018   66840
#
#        fuel_type                                             engine  \
# ...

# %%
car_sales["Seats"]=pd.Series([5])

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  toyota  White         150043      4   $4,000.00    5.0
# 1   honda    Red          87899      4   $5,000.00    NaN
# 2  toyota   Blue          32549      3   $7,000.00    NaN
# 3     bmw  Black          11179      5  $22,000.00    NaN
# 4  nissan  White         213095      4   $3,500.00    NaN
# 5  toyota  Green          99213      4   $4,500.00    NaN
# 6   honda   Blue          45698      4   $7,500.00    NaN
# 7   honda   Blue          54738      4   $7,000.00    NaN
# 8  toyota  White          60000      4   $6,250.00    NaN
# 9  nissan  White          31600      4   $9,700.00    NaN

# %%
car_sales["Seats"].fillna(5,inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5276\2261095283.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales["Seats"].fillna(5,inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  toyota  White         150043      4   $4,000.00    5.0
# 1   honda    Red          87899      4   $5,000.00    5.0
# 2  toyota   Blue          32549      3   $7,000.00    5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0
# 4  nissan  White         213095      4   $3,500.00    5.0
# 5  toyota  Green          99213      4   $4,500.00    5.0
# 6   honda   Blue          45698      4   $7,500.00    5.0
# 7   honda   Blue          54738      4   $7,000.00    5.0
# 8  toyota  White          60000      4   $6,250.00    5.0
# 9  nissan  White          31600      4   $9,700.00    5.0

# %%
car_sales_shuffled=car_sales.sample(frac=1)#this shuffle randomly

# %%
car_sales_shuffled.sample(frac=0.1)# what % of data
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats
# 5  toyota  Green          99213      4  $4,500.00    5.0

# %%
car_sales_shuffled.reset_index(drop=True,inplace=True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  nissan  White          31600      4   $9,700.00    5.0
# 1  toyota  White         150043      4   $4,000.00    5.0
# 2  toyota  Green          99213      4   $4,500.00    5.0
# 3  toyota   Blue          32549      3   $7,000.00    5.0
# 4   honda    Red          87899      4   $5,000.00    5.0
# 5  nissan  White         213095      4   $3,500.00    5.0
# 6     bmw  Black          11179      5  $22,000.00    5.0
# 7   honda   Blue          54738      4   $7,000.00    5.0
# 8   honda   Blue          45698      4   $7,500.00    5.0
# 9  toyota  White          60000      4   $6,250.00    5.0

# %%
car_sales["Odometer (KM)"]=car_sales["Odometer (KM)"].apply(lambda x:x/1.60934)
# KM to Miles Conversion through .apply function

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  toyota  White   93232.629525      4   $4,000.00    5.0
# 1   honda    Red   54618.042179      4   $5,000.00    5.0
# 2  toyota   Blue   20225.061205      3   $7,000.00    5.0
# 3     bmw  Black    6946.325823      5  $22,000.00    5.0
# 4  nissan  White  132411.423316      4   $3,500.00    5.0
# 5  toyota  Green   61648.253321      4   $4,500.00    5.0
# 6   honda   Blue   28395.491319      4   $7,500.00    5.0
# 7   honda   Blue   34012.700859      4   $7,000.00    5.0
# 8  toyota  White   37282.364199      4   $6,250.00    5.0
# 9  nissan  White   19635.378478      4   $9,700.00    5.0
